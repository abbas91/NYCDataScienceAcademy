# %%
# %pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy import stats
import pandas as pd
import numpy as np

# %%
n = int(1e3)
df = pd.DataFrame({'norm': stats.norm.rvs(size = n),\
                   'binomial': stats.binom.rvs(10, 0.5, size = n),\
                   'poisson': stats.poisson.rvs(5, size = n),\
                   't': stats.t.rvs(30, size = n)})
plt.hist(df.norm)
# Out:
# (array([   3.,   11.,   48.,  132.,  272.,  267.,  164.,   76.,   24.,    3.]),
#  array([-3.68288434, -2.97529926, -2.26771417, -1.56012909, -0.85254401,
#         -0.14495892,  0.56262616,  1.27021124,  1.97779633,  2.68538141,
#          3.39296649]),
#  <a list of 10 Patch objects>)

# %%
import seaborn as sns
plt.hist(df.norm)
# Out:
# (array([   3.,   11.,   48.,  132.,  272.,  267.,  164.,   76.,   24.,    3.]),
#  array([-3.68288434, -2.97529926, -2.26771417, -1.56012909, -0.85254401,
#         -0.14495892,  0.56262616,  1.27021124,  1.97779633,  2.68538141,
#          3.39296649]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Unvariate Plot

# %%
np.random.seed(2)
x = np.random.randn(n)
y = 2*x + np.random.rand(n)

# %%
sns.kdeplot(x, shade=True, label='Estimated PDF')

# %% [markdown]
# ** Exercise** Modify the code above to obtain the plot below:

# %%
### Your code here
sns.kdeplot(x, shade=True, label='Estimated PDF')
z =sorted(x)
plt.plot(z, stats.norm(0,1).pdf(z), color='red')

# %%
sns.distplot(x)

# %%
sns.boxplot(df)

# %%
df = pd.DataFrame(df, columns=['t', 'norm',\
                               'binomial', 'poisson'])
sns.violinplot(df)

# %% [markdown]
# ## Bivariate Plot

# %%
sns.kdeplot(x, y, shade=True)

# %% [markdown]
# **Exercise** Sketch the 2D density plot for the normal random sample and the binomial random sample in our `df`.

# %%
#### Your code here

# %%
sns.jointplot(df.norm, df.t)

# %% [markdown]
# **Exercise**
# - Visualize the variables x and y we created in the previous slide. Explain the pearsonr and p for this case.
# - Visualize with the same function as above. This time specify kind="hex", kind="reg" and kind="kde", respectively.

# %%
#### Your code here

# %% [markdown]
# ## Multivariate Plot

# %%
sns.corrplot(df)

# %%
titanic = sns.load_dataset("titanic").dropna()

# %%
sns.corrplot(titanic)

# %% [markdown]
# ## Advanced Plot

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot("total_bill", "tip", tips)

# %%
sns.lmplot("total_bill", "tip", tips, hue="sex", palette="Set2");

# %% [markdown]
# **Exercise** Make the same visualization as in the previous slide. This time group the data according to that if the observation is a smoker or not.

# %%
#### Your code here

# %% [markdown]
# ### Advanced plot: fitting

# %%
sns.regplot(tips.total_bill, tips.tip)

# %%
SexGrid = sns.FacetGrid(tips, col='sex',hue="sex", palette="Set1")
SexGrid.map(sns.distplot, "tip");

# %%
tipsGrid = sns.FacetGrid(tips, row='sex', col='smoker',\
                               hue='time', palette="Set2")
tipsGrid.map(sns.regplot, 'total_bill', 'tip')
tipsGrid.add_legend()

# %%
tipGrid = sns.PairGrid(tips)
tipGrid.map(plt.scatter)

# %% [markdown]
# **Exercise** Download the iris data frame built in the seaborn package.

# %%
iris = sns.load_dataset("iris")

# %% [markdown]
# Then pair the four numeric features and sketch scatter plot for each pair.m

# %%
#### Your code here

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)

# %%
g = sns.PairGrid(iris, hue = 'species', palette='Set2',\
           hue_kws={'cmap':['Greens','Oranges','Blues']})
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
g.add_legend()
